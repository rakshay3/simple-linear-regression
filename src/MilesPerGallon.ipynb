# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

df = pd.read_csv("auto-mpg.csv")
df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# 1            70       1          buick skylark 320
# 2            70       1         plymouth satellite
# 3            70       1              amc rebel sst
# 4            70       1                ford torino
# ..          ...     ...                        ...
# 393          82       1            ford mustang gl
# 394          82       2                  vw pickup
# 395          82       1              dodge rampage
# 396          82       1                ford ranger
# 397          82       1                 chevy s-10
#
# [398 rows x 9 columns]

# %%
mpg_df = df[['mpg','weight']]
mpg_df
# Out:
#       mpg  weight
# 0    18.0    3504
# 1    15.0    3693
# 2    18.0    3436
# 3    16.0    3433
# 4    17.0    3449
# ..    ...     ...
# 393  27.0    2790
# 394  44.0    2130
# 395  32.0    2295
# 396  28.0    2625
# 397  31.0    2720
#
# [398 rows x 2 columns]

# %%
X = mpg_df[['weight']]
y = mpg_df['mpg']
model = LinearRegression()
model.fit(X,y)
model.coef_
# Out:
# array([-0.00767661])

# %%
model.intercept_
# Out:
# 46.31736442026565

# %%
model.predict(mpg_df[['weight']])

r2_score(
    y_true = mpg_df.mpg,
    y_pred = model.predict(mpg_df[['weight']])
)
# Out:
# 0.6917929800341573

# %%
# !pip install plotnine

from plotnine import ggplot, aes, geom_point, geom_line
from plotnine.themes import theme_minimal

mpg_df['fitted'] = model.predict(mpg_df[['weight']])
# Out:
# Collecting plotnine
#   Downloading plotnine-0.14.4-py3-none-any.whl.metadata (9.3 kB)
# Requirement already satisfied: matplotlib>=3.8.0 in a:\anaconda\lib\site-packages (from plotnine) (3.9.2)
# Requirement already satisfied: pandas>=2.2.0 in a:\anaconda\lib\site-packages (from plotnine) (2.2.2)
# Collecting mizani~=0.13.0 (from plotnine)
#   Downloading mizani-0.13.1-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: numpy>=1.23.5 in a:\anaconda\lib\site-packages (from plotnine) (1.26.4)
# Requirement already satisfied: scipy>=1.8.0 in a:\anaconda\lib\site-packages (from plotnine) (1.13.1)
# Requirement already satisfied: statsmodels>=0.14.0 in a:\anaconda\lib\site-packages (from plotnine) (0.14.2)
# Requirement already satisfied: contourpy>=1.0.1 in a:\anaconda\lib\site-packages (from matplotlib>=3.8.0->plotnine) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in a:\anaconda\lib\site-packages (from matplotlib>=3.8.0->plotnine) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in a:\anaconda\lib\site-packages (from matplotlib>=3.8.0->plotnine) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in a:\anaconda\lib\site-packages (from matplotlib>=3.8.0->plotnine) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in a:\anaconda\lib\site-packages (from matplotlib>=3.8.0->plotnine) (24.1)
# Requirement already satisfied: pillow>=8 in a:\anaconda\lib\site-packages (from matplotlib>=3.8.0->plotnine) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in a:\anaconda\lib\site-packages (from matplotlib>=3.8.0->plotnine) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in a:\anaconda\lib\site-packages (from matplotlib>=3.8.0->plotnine) (2.9.0.post0)
# Requirement already satisfied: tzdata in a:\anaconda\lib\site-packages (from mizani~=0.13.0->plotnine) (2023.3)
# Requirement already satisfied: pytz>=2020.1 in a:\anaconda\lib\site-packages (from pandas>=2.2.0->plotnine) (2024.1)
# Requirement already satisfied: patsy>=0.5.6 in a:\anaconda\lib\site-packages (from statsmodels>=0.14.0->plotnine) (0.5.6)
# Requirement already satisfied: six in a:\anaconda\lib\site-packages (from patsy>=0.5.6->statsmodels>=0.14.0->plotnine) (1.16.0)
# Downloading plotnine-0.14.4-py3-none-any.whl (1.3 MB)
#    ---------------------------------------- 0.0/1.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.3/1.3 MB ? eta -:--:--
#    ------------------------ --------------- 0.8/1.3 MB 2.0 MB/s eta 0:00:01
#    -------------------------------- ------- 1.0/1.3 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------------- 1.3/1.3 MB 2.1 MB/s eta 0:00:00
# Downloading mizani-0.13.1-py3-none-any.whl (127 kB)
# Installing collected packages: mizani, plotnine
# Successfully installed mizani-0.13.1 plotnine-0.14.4
# C:\Users\raksh\AppData\Local\Temp\ipykernel_16760\1579835337.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
ggplot(aes('weight', 'mpg'),mpg_df)\
  + geom_point(alpha = 0.5, color = "#2c3e50")\
  + geom_line(aes(y = 'fitted'),color = 'blue')\
  + theme_minimal()
